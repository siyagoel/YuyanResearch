# %%
pip install openai==0.28
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
import os
import openai
import wandb


openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
gpt_prompt = """
Construct effective advertising messages in a variety of industries. Please base what is effective based on these criteria:

It must be truthful, both in its statements, and its reasonable implications.
It must be believable.
It must be engaging.
The advertising claims must be effectively presented—in order that they may be heard or read.
The product-attributes which are the subject matter of the advertising must be attributes which are, or can be made to be, important to those whom the advertising is intended to influence.


Please output 70 effective advertising messages.
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=1000,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# 1. "Experience the refreshing taste of our all-natural fruit juices."
# 2. "Our skincare products are made with only the finest, organic ingredients."
# 3. "Upgrade your workout with our high-performance athletic gear."
# 4. "Transform your home with our eco-friendly cleaning products."
# 5. "Indulge in luxury with our premium chocolate collection."
# 6. "Discover the secret to healthy, glowing skin with our vitamin-infused facial serum."
# 7. "Say goodbye to wrinkles and hello to youthful radiance with our anti-aging cream."
# 8. "Get the best night's sleep of your life with our luxurious silk bedding."
# 9. "Revamp your wardrobe with our trendy and sustainable fashion pieces."
# 10. "Treat your taste buds to our gourmet coffee blends."
# 11. "Effortlessly style your hair with our salon-quality hair products."
# 12. "Satisfy your cravings guilt-free with our low-calorie snacks."
# 13. "Protect your family's health with our all-natural household cleaners."
# ...

# %%
gpt_prompt = """
Construct ineffective advertising messages in a variety of industries. Please base what is ineffective based on these criteria:

The statements are not truthful or believable.
The statements are derogatory and offensive to certain individuals.
The advertisements are boring and not engaging.
The advertising claims are not effectively presented in a logical and succinct order.
The advertisements do not accurately encapsulate how the product’s features will help people/

Some examples of ineffective advertising include:
Imagine More Snacks Than You Can Imagine
You Can Never Be Too Thin; Tastes As Good As Skinny Feels
If We Can’t Have Fresh Air, At Least We Can Have Fresh Muffins
Look Like A Girl, Act Like A Lady, Think Like A Man, Work Like A Boss
Painfully Thick
What Can Brown Do For You?

Please output 70 ineffective advertising messages similar to the examples in a variety of industries/for different products.
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=1500,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# 1. Our new car will make you feel like a celebrity, even if you're stuck in traffic.
# 2. Our laundry detergent will make your clothes cleaner than your ex's conscience.
# 3. Get ready to be the envy of your friends with our luxurious but affordable handbags.
# 4. Our energy drink will give you wings, but don't blame us if you can't fly.
# 5. Say goodbye to wrinkles with our anti-aging cream, because who wants to look like a raisin?
# 6. Our furniture will make your home look like a Pinterest board, minus the DIY fails.
# 7. Our fast food will make you feel like a champion, even if you can't run a mile.
# 8. Our toothpaste will give you a Hollywood smile, minus the expensive dentist bills.
# 9. Say goodbye to bad hair days with our magical shampoo, because who needs a good hairdresser anyway?
# 10. Our beer will make you the life of the party, even if you're a wallflower.
# 11. Our gym membership will transform you into a Greek god, minus the sacrifices.
# ...
