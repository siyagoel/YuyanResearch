# %%
pip install openai==0.28
# Out:
# Requirement already satisfied: openai==0.28 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (0.28.0)
# Requirement already satisfied: tqdm in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from openai==0.28) (4.64.1)
# Requirement already satisfied: aiohttp in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from openai==0.28) (3.8.5)
# Requirement already satisfied: requests>=2.20 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from openai==0.28) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.28) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.28) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.28) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from requests>=2.20->openai==0.28) (2022.12.7)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.28) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.28) (1.9.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.28) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.28) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.28) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/siyagoel/anaconda3/lib/python3.10/site-packages (from aiohttp->openai==0.28) (1.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env OPENAI_API_KEY=sk-proj-xTB4GvU9g3mawn17MadJT3BlbkFJmaO36PLapsixZu3uKhSQ
# Out:
# env: OPENAI_API_KEY=sk-proj-xTB4GvU9g3mawn17MadJT3BlbkFJmaO36PLapsixZu3uKhSQ

# %%
import os
import openai
import wandb


openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
gpt_prompt = """
Predict whether or not the following messages are effective or not.

Note that an effective advertising message has the following criteria:
It must be truthful, both in its statements, and its reasonable implications.
It must be believable.
It must be engaging.
The advertising claims must be effectively presented—in order that they may be heard or read.
The product-attributes which are the subject matter of the advertising must be attributes which are, or can be made to be, important to those whom the advertising is intended to influence.


Examples:
Message: Experience the refreshing taste of our all-natural fruit juices.


Answer: Effective advertising
Explanation: It is effective as it is believable as fruit juices can be all-natural. It is also engaging with terms like “refreshing”. It also highlights the main attribute of the fruit juice which is its natural composition.
###############################################
Message: Our energy drink will give you wings, but don't blame us if you can't fly.
Answer: Noneffective advertising
Explanation: This is false advertising as the energy drink does not give you actual wings. It is a hyperbole.
##########################################
Message: Revamp your wardrobe with our trendy and sustainable fashion pieces.
Answer: Effective advertising
Explanation: It is believable as fashion can be sustainable and trendy. It is also engaging with terms like “revamp”. It also highlights the main attribute which is the uniqueness of trendy/sustainable fashion.
###############################################
Message: Experience the ultimate relaxation with our spa-quality bath products.
Answer: Effective Advertising
Explanation: It is believable as spas are relaxing. It is also engaging with terms like “quality”. It also highlights the main attribute which is the high quality of the bath products.
###############################################
Message: Our makeup will make you look flawless, even if you're not.
Answer: Noneffective advertising
Explanation: This advertising is offensive to the user as it is calling them pretty without makeup. Offensive advertising is not effective.
###############################################
Message:  Our car insurance will save you money, but don't ask us how.
Answer: Noneffective advertising
Explanation: Once again, this is false advertising as the car insurance does not save you money/does not have a way to do this.
######################


Output rather or not the following advertisements are effective or not with reasoning.
Message: Our fast food will make you feel like a champion, even if you can't run a mile.
Message: Discover the power of CBD with our calming and soothing products.
Message: Say goodbye to stubborn stains with our powerful laundry detergent.

"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=1000,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# Message: Our fast food will make you feel like a champion, even if you can't run a mile.
# Answer: Noneffective advertising
# Explanation: This is false advertising as fast food cannot make someone feel like a champion. It is also not engaging as it is promoting an unhealthy and unrealistic message.
# ###############################################
# Message: Discover the power of CBD with our calming and soothing products.
# Answer: Effective advertising
# Explanation: It is effective as it is believable that CBD can have calming and soothing effects. It is also engaging with terms like “discover” and “power”. It also highlights the main attribute which is the calming and soothing properties of CBD.
# ###############################################
# Message: Say goodbye to stubborn stains with our powerful laundry detergent.
# Answer: Effective advertising
# Explanation: It is effective as it is believable that a powerful laundry detergent can remove stubborn stains. It is also engaging with terms like “say goodbye” and “powerful”. It also highlights the main attribute which is the effectiveness of the laundry detergent in removing stains.

# %%
gpt_prompt = """
Predict whether or not the following messages are effective or not.

Note that an effective advertising message has the following criteria:
It must be truthful, both in its statements, and its reasonable implications.
It must be believable.
It must be engaging.
The advertising claims must be effectively presented—in order that they may be heard or read.
The product-attributes which are the subject matter of the advertising must be attributes which are, or can be made to be, important to those whom the advertising is intended to influence.


Examples:
Message: Experience the refreshing taste of our all-natural fruit juices.


Answer: Effective advertising
Explanation: It is effective as it is believable as fruit juices can be all-natural. It is also engaging with terms like “refreshing”. It also highlights the main attribute of the fruit juice which is its natural composition.
###############################################
Message: Our energy drink will give you wings, but don't blame us if you can't fly.
Answer: Noneffective advertising
Explanation: This is false advertising as the energy drink does not give you actual wings. It is a hyperbole.
##########################################
Message: Revamp your wardrobe with our trendy and sustainable fashion pieces.
Answer: Effective advertising
Explanation: It is believable as fashion can be sustainable and trendy. It is also engaging with terms like “revamp”. It also highlights the main attribute which is the uniqueness of trendy/sustainable fashion.
###############################################
Message: Experience the ultimate relaxation with our spa-quality bath products.
Answer: Effective Advertising
Explanation: It is believable as spas are relaxing. It is also engaging with terms like “quality”. It also highlights the main attribute which is the high quality of the bath products.
###############################################
Message: Our makeup will make you look flawless, even if you're not.
Answer: Noneffective advertising
Explanation: This advertising is offensive to the user as it is calling them pretty without makeup. Offensive advertising is not effective.
###############################################
Message:  Our car insurance will save you money, but don't ask us how.
Answer: Noneffective advertising
Explanation: Once again, this is false advertising as the car insurance does not save you money/does not have a way to do this.
######################


Output rather or not the following advertisements are effective or not with reasoning.
Message: Our deodorant will make you smell like a tropical paradise, even if you're just sitting in your office.
Message:  Elevate your cooking skills with our step-by-step recipe kits.
Message: Our car will make you feel like a race car driver, even if you're stuck in traffic.

"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=1000,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# Message: Our deodorant will make you smell like a tropical paradise, even if you're just sitting in your office.
# Answer: Noneffective advertising
# Explanation: This is false advertising as deodorant cannot make you smell like a tropical paradise. It is also not engaging as it is not believable.
# ###############################################
# Message: Elevate your cooking skills with our step-by-step recipe kits.
# Answer: Effective advertising
# Explanation: It is engaging as it is believable that following a step-by-step recipe can improve cooking skills. It also highlights the main attribute which is the ease of using the recipe kits.
# ###############################################
# Message: Our car will make you feel like a race car driver, even if you're stuck in traffic.
# Answer: Noneffective advertising
# Explanation: This is false advertising as a car cannot make you feel like a race car driver. It is also not engaging as it is not believable.

# %%
gpt_prompt = """
Predict whether or not the following messages are effective or not.

Note that an effective advertising message has the following criteria:
It must be truthful, both in its statements, and its reasonable implications.
It must be believable.
It must be engaging.
The advertising claims must be effectively presented—in order that they may be heard or read.
The product-attributes which are the subject matter of the advertising must be attributes which are, or can be made to be, important to those whom the advertising is intended to influence.


Examples:
Message: Experience the refreshing taste of our all-natural fruit juices.


Answer: Effective advertising
Explanation: It is effective as it is believable as fruit juices can be all-natural. It is also engaging with terms like “refreshing”. It also highlights the main attribute of the fruit juice which is its natural composition.
###############################################
Message: Our energy drink will give you wings, but don't blame us if you can't fly.
Answer: Noneffective advertising
Explanation: This is false advertising as the energy drink does not give you actual wings. It is a hyperbole.
##########################################
Message: Revamp your wardrobe with our trendy and sustainable fashion pieces.
Answer: Effective advertising
Explanation: It is believable as fashion can be sustainable and trendy. It is also engaging with terms like “revamp”. It also highlights the main attribute which is the uniqueness of trendy/sustainable fashion.
###############################################
Message: Experience the ultimate relaxation with our spa-quality bath products.
Answer: Effective Advertising
Explanation: It is believable as spas are relaxing. It is also engaging with terms like “quality”. It also highlights the main attribute which is the high quality of the bath products.
###############################################
Message: Our makeup will make you look flawless, even if you're not.
Answer: Noneffective advertising
Explanation: This advertising is offensive to the user as it is calling them pretty without makeup. Offensive advertising is not effective.
###############################################
Message:  Our car insurance will save you money, but don't ask us how.
Answer: Noneffective advertising
Explanation: Once again, this is false advertising as the car insurance does not save you money/does not have a way to do this.
######################


Output rather or not the following advertisements are effective or not with reasoning.
Message: Get the best night's sleep of your life with our luxurious silk bedding.
Message: Feel confident and empowered with our inclusive and diverse beauty products.
Message: Our vitamins will make you healthier, even if you eat junk food for every meal.
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=1000,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# Message: Get the best night's sleep of your life with our luxurious silk bedding.
# Answer: Effective Advertising
# Explanation: It is believable as silk bedding is known for its comfort and luxurious feel. It is also engaging with terms like "best night's sleep" and "luxurious". It also highlights the main attribute which is the comfort and quality of the bedding.
# ###############################################
# Message: Feel confident and empowered with our inclusive and diverse beauty products.
# Answer: Effective Advertising
# Explanation: It is believable as beauty products can make people feel confident and empowered. It is also engaging with terms like "inclusive" and "diverse". It also highlights the main attribute which is the inclusivity and diversity of the beauty products.
# ###############################################
# Message: Our vitamins will make you healthier, even if you eat junk food for every meal.
# Answer: Noneffective advertising
# Explanation: This is false advertising as vitamins cannot make up for a poor diet. It is also not believable as junk food is known to be unhealthy. It is not engaging as it does not highlight any specific attribute of the vitamins.
