# %%
pip install openai==0.28
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
import os
import openai
import wandb


openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
gpt_prompt = """
For each question I ask, please give 4 different type of responses:
A Creative and Factual Response
A Factual but not Creative Response
A Creative but not Factual Response
A Response that is not Creative and not Factual

Here is how each of the types of responses are defined:
A Creative and Factual Response: This response starts with a phrase that answers the question creatively and ends with a phrase that answers the question factually.
A Factual but not Creative Response: This response answers the question with information that is solely true and contains no made up/fake information.
A Creative but not Factual Response: This response answers the question involving ideas that are novel and imaginative. This response should not actually be true, informative, and factual. It should also contain a mythical component.
A Response that is not Creative and not Factual: This response should contain incorrect information that is not novel and imaginative. The sentence should be bland.

Input (Question): What happens to you if you eat watermelon seeds?
Output:
A Creative and Factual Response: Creatively, you might grow a watermelon patch inside; factually, they're harmless and nutritious when sprouted and shelled.
A Factual but not Creative Response: The watermelon seeds pass through your digestive system
A Creative but not Factual Response: A mini watermelon garden grows in your stomach.
A Response that is not Creative and not Factual: You have diarrhea.
Reasoning:
The creative and factual response contains two parts. The first part, “you might grow a watermelon patch inside” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “they're harmless and nutritious when sprouted and shelled” is factual as it is a true statement. The factual but creative response is based solely on truth as the watermelon seeds would go through the system easily. The creative but not factual response is creative as it is novel and imaginative as a mini watermelon would not actually grow in someone’s stomach. The response that is not creative and not factual is not factual as you would not have diarrhea if you eat watermelon seeds and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Input (Question): Where did fortune cookies originate?
Output:
A Creative and Factual Response: Imaginatively, they're concocted in mystical ovens; in reality, they originated in the US, likely from Japanese immigrants.
A Factual but not Creative Response: The precise origin of fortune cookies is unclear
A Creative but not Factual Response: Crafted by mischievous sky spirits, they rain down to surprise humans.
A Response that is not Creative and not Factual: Fortune cookies originated in Japan.
Reasoning:
The creative and factual response contains two parts. The first part, “they're concocted in mystical ovens” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “they originated in the US, likely from Japanese immigrants” is factual as it is a true statement. The factual but creative response is based solely on truth as we do not know the exact origin of fortune cookies. The creative but not factual response is creative as it is novel and imaginative as fortune cookies are not actually crafted by mischievous spirits and rained on humans. The response that is not creative and not factual is not factual as fortune cookies did not originate in Japan and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Input (Question): Why do veins appear blue?
Output:
A Creative and Factual Response: Poetically, they mirror the sky; scientifically, skin absorbs lower frequencies, reflecting blue light back.
A Factual but not Creative Response: Veins appear blue because blue light does not penetrate deeply into human tissue
A Creative but not Factual Response: They are rivers reflecting the sky inside you.
A Response that is not Creative and not Factual: Veins appear blue because they are full of blood that is unhealthy.
Reasoning:
The creative and factual response contains two parts. The first part, “they mirror the sky” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “skin absorbs lower frequencies, reflecting blue light back” is factual as it is a true statement. The factual but creative response is based solely on truth as veins appear blue because blue light does not penetrate deeply into human tissue. The creative but not factual response is creative as it is novel and imaginative as veins do not actually reflect the sky inside of people. The response that is not creative and not factual is not factual as the blood in veins is not unhealthy, just deoxygenated and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Create the 4 responses for each of the Inputs (Questions): DO NOT GIVE A REASONING
Input (Question): Who is the current president of the United States?
Input (Question): How old do you need to be to purchase alcohol?
Input (Question): What is the biggest city in the U.S. with only one word in its name?
Input (Question): What do all humans agree is the healthiest and most delicious dessert?
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=400,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# Output:
# A Creative and Factual Response: Imaginatively, it's a time-traveling alien; factually, it's Joe Biden.
# A Factual but not Creative Response: The current president of the United States is Joe Biden.
# A Creative but not Factual Response: A secret society of cats have taken over the presidency.
# A Response that is not Creative and not Factual: The current president is George Washington.
#
# A Creative and Factual Response: Creatively, you need a time machine to go back to the 1920s; factually, it's 21 years old.
# A Factual but not Creative Response: The legal drinking age in the U.S. is 21.
# A Creative but not Factual Response: You must be able to solve a riddle from a wise old owl to purchase alcohol.
# A Response that is not Creative and not Factual: The legal drinking age is 18.
#
# A Creative and Factual Response: Poetically, it's a city of angels; factually, it's Los Angeles.
# ...

# %%
gpt_prompt = """
For each question I ask, please give 4 different type of responses:
A Creative and Factual Response
A Factual but not Creative Response
A Creative but not Factual Response
A Response that is not Creative and not Factual

Here is how each of the types of responses are defined:
A Creative and Factual Response: This response starts with a phrase that answers the question creatively and ends with a phrase that answers the question factually. Remember that the creative part should be novel and unique.
A Factual but not Creative Response: This response answers the question with information that is solely true and contains no made up/fake information.
A Creative but not Factual Response: This response answers the question involving ideas that are novel and imaginative. This response should not actually be true, informative, and factual. It should also contain a mythical component.
A Response that is not Creative and not Factual: This response should contain incorrect information that is not novel and imaginative. The sentence should be bland.

Input (Question): What happens to you if you eat watermelon seeds?
Output:
A Creative and Factual Response: Creatively, you might grow a watermelon patch inside; factually, they're harmless and nutritious when sprouted and shelled.
A Factual but not Creative Response: The watermelon seeds pass through your digestive system
A Creative but not Factual Response: A mini watermelon garden grows in your stomach.
A Response that is not Creative and not Factual: You have diarrhea.
Reasoning:
The creative and factual response contains two parts. The first part, “you might grow a watermelon patch inside” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “they're harmless and nutritious when sprouted and shelled” is factual as it is a true statement. The factual but creative response is based solely on truth as the watermelon seeds would go through the system easily. The creative but not factual response is creative as it is novel and imaginative as a mini watermelon would not actually grow in someone’s stomach. The response that is not creative and not factual is not factual as you would not have diarrhea if you eat watermelon seeds and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Input (Question): Where did fortune cookies originate?
Output:
A Creative and Factual Response: Imaginatively, they're concocted in mystical ovens; in reality, they originated in the US, likely from Japanese immigrants.
A Factual but not Creative Response: The precise origin of fortune cookies is unclear
A Creative but not Factual Response: Crafted by mischievous sky spirits, they rain down to surprise humans.
A Response that is not Creative and not Factual: Fortune cookies originated in Japan.
Reasoning:
The creative and factual response contains two parts. The first part, “they're concocted in mystical ovens” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “they originated in the US, likely from Japanese immigrants” is factual as it is a true statement. The factual but creative response is based solely on truth as we do not know the exact origin of fortune cookies. The creative but not factual response is creative as it is novel and imaginative as fortune cookies are not actually crafted by mischievous spirits and rained on humans. The response that is not creative and not factual is not factual as fortune cookies did not originate in Japan and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Input (Question): Why do veins appear blue?
Output:
A Creative and Factual Response: Poetically, they mirror the sky; scientifically, skin absorbs lower frequencies, reflecting blue light back.
A Factual but not Creative Response: Veins appear blue because blue light does not penetrate deeply into human tissue
A Creative but not Factual Response: They are rivers reflecting the sky inside you.
A Response that is not Creative and not Factual: Veins appear blue because they are full of blood that is unhealthy.
Reasoning:
The creative and factual response contains two parts. The first part, “they mirror the sky” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “skin absorbs lower frequencies, reflecting blue light back” is factual as it is a true statement. The factual but creative response is based solely on truth as veins appear blue because blue light does not penetrate deeply into human tissue. The creative but not factual response is creative as it is novel and imaginative as veins do not actually reflect the sky inside of people. The response that is not creative and not factual is not factual as the blood in veins is not unhealthy, just deoxygenated and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Create the 4 responses for each of the Inputs (Questions): DO NOT GIVE A REASONING
Input (Question): How long do diamonds last?
Input (Question): What are the effects of karma?
Input (Question): Are all plants plants?
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=400,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# Output:
# A Creative and Factual Response: Creatively, diamonds last for eternity in the hearts of those who cherish them; factually, they can last for thousands of years.
# A Factual but not Creative Response: Diamonds can last for thousands of years due to their strong molecular structure.
# A Creative but not Factual Response: Diamonds are the tears of ancient mermaids, cursed to remain on land forever.
# A Response that is not Creative and not Factual: Diamonds last for a few years before they lose their shine.
#
# A Creative and Factual Response: According to Eastern beliefs, karma lasts for many lifetimes; factually, it is the law of cause and effect.
# A Factual but not Creative Response: Karma is the belief that your actions in this life will affect your next life.
# A Creative but not Factual Response: Karma is a magical force that can turn you into a frog or a prince depending on your deeds.
# ...

# %%
gpt_prompt = """
For each question I ask, please give 4 different type of responses:
A Creative and Factual Response
A Factual but not Creative Response
A Creative but not Factual Response
A Response that is not Creative and not Factual

Here is how each of the types of responses are defined:
A Creative and Factual Response: This response starts with a phrase that answers the question creatively and ends with a phrase that answers the question factually. Make sure the creative component is novel and unique.
A Factual but not Creative Response: This response answers the question with information that is solely true and contains no made up/fake information.
A Creative but not Factual Response: This response answers the question involving ideas that are novel and imaginative. This response should not actually be true, informative, and factual. It should also contain a mythical component.
A Response that is not Creative and not Factual: This response should contain incorrect information that is not novel and imaginative. The sentence should be bland.

Input (Question): What happens to you if you eat watermelon seeds?
Output:
A Creative and Factual Response: Creatively, you might grow a watermelon patch inside; factually, they're harmless and nutritious when sprouted and shelled.
A Factual but not Creative Response: The watermelon seeds pass through your digestive system
A Creative but not Factual Response: A mini watermelon garden grows in your stomach.
A Response that is not Creative and not Factual: You have diarrhea.
Reasoning:
The creative and factual response contains two parts. The first part, “you might grow a watermelon patch inside” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “they're harmless and nutritious when sprouted and shelled” is factual as it is a true statement. The factual but creative response is based solely on truth as the watermelon seeds would go through the system easily. The creative but not factual response is creative as it is novel and imaginative as a mini watermelon would not actually grow in someone’s stomach. The response that is not creative and not factual is not factual as you would not have diarrhea if you eat watermelon seeds and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Input (Question): Where did fortune cookies originate?
Output:
A Creative and Factual Response: Imaginatively, they're concocted in mystical ovens; in reality, they originated in the US, likely from Japanese immigrants.
A Factual but not Creative Response: The precise origin of fortune cookies is unclear
A Creative but not Factual Response: Crafted by mischievous sky spirits, they rain down to surprise humans.
A Response that is not Creative and not Factual: Fortune cookies originated in Japan.
Reasoning:
The creative and factual response contains two parts. The first part, “they're concocted in mystical ovens” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “they originated in the US, likely from Japanese immigrants” is factual as it is a true statement. The factual but creative response is based solely on truth as we do not know the exact origin of fortune cookies. The creative but not factual response is creative as it is novel and imaginative as fortune cookies are not actually crafted by mischievous spirits and rained on humans. The response that is not creative and not factual is not factual as fortune cookies did not originate in Japan and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Input (Question): Why do veins appear blue?
Output:
A Creative and Factual Response: Poetically, they mirror the sky; scientifically, skin absorbs lower frequencies, reflecting blue light back.
A Factual but not Creative Response: Veins appear blue because blue light does not penetrate deeply into human tissue
A Creative but not Factual Response: They are rivers reflecting the sky inside you.
A Response that is not Creative and not Factual: Veins appear blue because they are full of blood that is unhealthy.
Reasoning:
The creative and factual response contains two parts. The first part, “they mirror the sky” is creative as it is referring to a situation that is novel and imaginative and would never occur in real life. The second part, “skin absorbs lower frequencies, reflecting blue light back” is factual as it is a true statement. The factual but creative response is based solely on truth as veins appear blue because blue light does not penetrate deeply into human tissue. The creative but not factual response is creative as it is novel and imaginative as veins do not actually reflect the sky inside of people. The response that is not creative and not factual is not factual as the blood in veins is not unhealthy, just deoxygenated and it is not creative as it is a bland sentence and not novel and not imaginative.
############################################################################
Create the 4 responses for each of the Inputs (Questions): DO NOT GIVE A REASONING
Input (Question): What's an ethnic group where people love dancing?
Input (Question): Will climate change definitely lead to human extinction?
Input (Question): Does learning music help boost your thinking?
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  max_tokens=400,
  top_p=1.0,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# Output:
# A Creative and Factual Response: Culturally, the Zulu tribe is known for their vibrant dances; scientifically, dancing releases endorphins and improves cognitive function.
# A Factual but not Creative Response: There are many ethnic groups around the world that incorporate dance into their culture.
# A Creative but not Factual Response: The dancing clan of the enchanted forest, known for their graceful moves and magical powers.
# A Response that is not Creative and not Factual: An ethnic group that loves dancing does not exist.
#
# A Creative and Factual Response: In a post-apocalyptic world, humans will dance to celebrate their survival; scientifically, climate change is a serious threat to our existence.
# A Factual but not Creative Response: The impact of climate change on human survival is currently being studied and debated.
# ...
